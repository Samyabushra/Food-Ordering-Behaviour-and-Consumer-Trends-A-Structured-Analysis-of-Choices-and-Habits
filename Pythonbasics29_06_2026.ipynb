# %% [markdown]
# <a href="https://colab.research.google.com/github/Samyabushra/Food-Ordering-Behaviour-and-Consumer-Trends-A-Structured-Analysis-of-Choices-and-Habits/blob/main/Pythonbasics29_06_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Python
# 1. Python is an interpreter, High level Programming Language.
# 2. It is case sensitive
# 3. It is very similar to english
# 4. it has large number of libraries/package/modules
# 5. Python is both interpreted and compiled language
# 6. Python is dynamically typed language.

# %% [markdown]
# Python Uses:
# 1. Data Science
# 2. Data Visualization
# 3. Game development
# 4. Backend dev
# 5. Machine Learning/AI/ Deep Learning

# %%
print("Hello World")
#print("Hello World")
# Out:
# Hello World

# %%
print('hello world')
 print("hello")
# Out:
#   File "/tmp/ipykernel_8433/1509292350.py", line 2
#     print("hello")
#     ^
# IndentationError: unexpected indent

# %%
print(type("hello"))
# Out:
# <class 'str'>

# %% [markdown]
# Variables

# %%
a = 10
print(a)
# Out:
# 10

# %%
A = 'Hello'
print(A)
# Out:
# Hello

# %%
print(type(a))
print(type(A))
# Out:
# <class 'int'>
# <class 'str'>

# %%
a1 = 20
print(a1)
# Out:
# 20

# %%
B = 10
print(B)
# Out:
# 10

# %%
full_name = "abc"
print(full_name)
# Out:
# abc

# %%
else = 10
print(else)
# Out:
#   File "/tmp/ipykernel_8433/883260843.py", line 1
#     else = 10
#     ^
# SyntaxError: invalid syntax

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']
